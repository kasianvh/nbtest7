# %% [markdown]
# ## Introductie
#
# Bij deze PO gaan jullie de gegevens uit het databestand "Speeddatingdata.csv" onderzoeken. Daarbij probeer je conclusies te trekken uit de data. We gaan ervan uit dat deze dataset een representatieve steekproef is van alle speeddates in de VS.
#
# Beschrijf bij elke vraag je gedachtegang en hoe je tot een oplossing bent gekomen en licht je antwoorden waar mogelijk toe met een geschikte (grafische) representatie. In de opgave wordt vaak een hint gegeven op welke manier de opgave is op te lossen (meestal draaitabel/pivot table), maar op een andere manier de vraag oplossen mag natuurlijk ook.
#
# Elke regel van het bestand bevat de gegevens van een date. Je ziet bijvoorbeeld in het eerste record dat het bij deze date om een 21 -jarige vrouw gaat met ID 10001, dat als doel opgegeven heeft om nieuwe mensen te ontmoeten. Haar gesprekspartner met ID 10011, in het record ID other genoemd, is 27 jaar.
#
# In een echte statistische wereld begin je een onderzoek met een onderzoeksvraag. De onderzoeksvraag die wij willen beantwoorden is: 'Wat beïnvloed de uitslag van speeddates?'. Om deze onderzoeksvraag te beantwoorden zijn speeddate events in de VS georganiseerd en is de dataset "Speeddatingdata.csv" uit voortgekomen. Nadat de data verzameld is begint het onderzoek met het verkennen van de data, zoals in vraag 1-5. Daarna gaat de onderzoeker proberen om "subvragen" met behulp van de dataset te beantwoorden, die helpen om een conclusie te kunnen trekken voor de hoofdvraag.

# %% [markdown]
# ## Verkennede fase

# %% [markdown]
# ###  Excel Tabellen
#
# Om vraag 1 tot en met 4 te beantwoorden is het handig om video 5 te bekijken. Video 5 legt uit hoe je een Excel tabel kunt maken om bepaalde informatie te zoeken in een dataset. Ook is het handig om video 1 van 06:10 tot en met 07:30 te bekijken.

# %% [markdown]
# ### Video 1

# %%
from IPython.display import YouTubeVideo
video_id = "9p7EGzXht44?si=gh5VTsbVH_kES8GW&t=370"
YouTubeVideo(video_id, width=600, height=400)
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="https://www.youtube.com/embed/9p7EGzXht44?si=gh5VTsbVH_kES8GW&t=370"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Video 5

# %%
video_id = "oJbAvHxa5TM"
YouTubeVideo(video_id, width=600, height=400)

# %% [markdown]
# Als je in de praktijk aan een dataset gaat werken, begin je met de verkenning van de data. Dit doen wij met de volgende vragen:
#
# 1. Beantwoord de volgende verkennende vragen:
#     - (a) Hoeveel mensen van elk geslacht heb je? $(1pt)$
#     - (b) Hoeveel mensen van elke leeftijd heb je? $(1pt)$
#     - (c) Hoeveel mensen vinden godsdienst belangrijk (imp religion ≥ 7)? $(1pt)$
#     - (d) Wat is de gemiddelde leeftijd bij mannen? Geef hiervan een interpretatie. $(1pt)$

# %% [markdown]
# 2. In deze vraag gaan we de data visualiseren. Hiervoor is het handig om video 5 gezien te hebben mocht je nog niet weten hoe je grafieken moet maken.
#     - (a) Maak een (of twee) histogram(men) die de leeftijd van mannen en vrouwen laat zien. Wat merk je op? $(2pt)$
#     - (b) Maak een cirkeldiagram (pie chart) van de verdeling van de rassen die mee hebben gedaan aan de speeddating. $(2pt)$
#     - (c) Wat betekent de " * " die je ziet in je cirkeldiagram? $(1pt)$

# %% [markdown]
# De onderzoekers hebben voorafgaand aan elk speeddate event aan de
# deelnemers naar hun interesses gevraagd. Zodoende konden ze van elke
# speeddate aangeven in hoeverre de interesses van de beide deelnemers
# overeenkwamen. Dat is terug te vinden in de variabele cor_int
# (correlation of interests).
# De correlatie is een getal tussen - 1 en 1 . Als de correlatie een
# positief getal is, dan is er sprake van gemeenschappelijke interesses.
# Hoe hoger de correlatie, hoe meer de interesses van de gesprekspartners
# overeenkomen.
#
# 3.  In deze opgave gaan we een boxplot maken. Hiervoor is het handig om
#     video 4 (vanaf 04:00) te bekijken als je nog niet weet hoe dit moet.
#
#     - (a) Maak een boxplot van de variabele \"cor int\". $(1pt)$
#
#     - (b)  Geef een schatting van het hoogste- en het laagste getal. Geef
#         ook een schatting van Q1, Q3 en de mediaan. $(1pt)$
#
#     - (c)  Bereken nu de gemiddelde, modus en mediaan. $(1pt)$

# %% [markdown]
# Het bestand telt 8388 records met daarin de gegevens van een speeddate.
# Omdat elke speeddate tweemaal beschreven wordt, zijn de gegevens van één
# speeddate te vinden in twee rijen . Fisman en lyengar hebben dus in
# totaal $\frac{8388}{2}=4194$ speeddates geanalyseerd. Dit betekent dat
# voor de hele dataset het volgende geldt: Als je de gegevens van de 4194
# speeddates wilt analyseren en niet alles dubbel wilt tellen, dan
# selecteer je bij de variabele gender alleen de mannen of alleen de
# vrouwen.
#
# 4.  Bereken hoeveel procent van de speeddates in deze onderzoeksgroep de
#     vrouwelijke deelnemer als doel had om nieuwe mensen te ontmoeten.
#     $(2pt)$
#
#     ***Hint: Ga als volgt te werk. ***
#     - (1) Hoeveel vrouwen deden in totaal
#     mee.
#     - (2) Hoeveel vrouwen hadden als doel om nieuwe mensen te ontmoeten.
#     - (3) Bereken het percentage.

# %% [markdown]
# 5.  Bereken bij welk percentage van de speeddates in deze
#     onderzoeksgroep de mannelijke deelnemers $0-<5$ jaar ouder (dus even
#     oud, $1,2,3$ of 4 jaar ouder) waren dan de vrouwelijke deelnemers.
#     $(4pt)$
#
#     *Hint: maak een kolom met leeftijdsverschil*

# %% [markdown]
# ![opgave%205.png](attachment:opgave%205.png)
#
# 6.
#     - (a) Wat is er met deelnemer met ID 10013 aan de hand? Beschrijf deze deelnemer. (1pt)
#     - (b) Wat kan je nu zeggen over de gehele dataset als het gaat om het aantal personen dat meedoet en het aantal speeddates? (1pt)

# %% [markdown]
# ### Draaitabellen
#
# Bij dit PO zal klaarblijkelijk zijn dat het gebruiken van een draaitabel
# of engels genaamd *pivot table* vaak terug komen. Dit komt vooral omdat
# draaitabellen grootte dataset kan omzetten in kleinere data sets.
# Draaitabellen kunnen ook helpen bij het filteren van veel overbodige
# informatie dat niet relevant is tot wat je aan het onderzoeken bent.
# Data-analyse dat met Excel wordt gedaan is dus ook vooral afhankelijk
# van het kunnen maken van een goede draaitabel die goed toepasbaar is op
# de gegeven probleem stelling.

# %% [markdown]
# ### Video 7

# %%
video_id = "RL3FUcZy2Ac"
YouTubeVideo(video_id, width=600, height=400)

# %% [markdown]
# ![Tabel%20frequentie%20polygoon%202.png](attachment:Tabel%20frequentie%20polygoon%202.png)
#
# *Figuur 1: Hulptabel voor het maken van een relatieve cumulatieve frequentiepolygoon*
#
# **Bekijk video 7: Draaitabellen**
#
# 7.
#     - (a) Voor één van de groepen, de mannen of de vrouwen, is godsdienst belangrijker dan voor de andere groep. Maak een draaitabel aan met importance relgion tegen over gender, vergelijkbaar als in figuur 1. $(1pt)$
#     - (b) Vinden mannen of vrouwen religie het belangrijkst in speeddaten?
#         Beantwoord deze vraag door een cumulatieve frequentiepolygoon te
#         maken van beide groepen (Met een cumulatieve frequentiepolygoon
#         kun je deze twee groepen met elkaar vergelijken). $(2pt)$
#
#     **Hint: Zet de draaitabel in: Show values as % of column total. Maak voor mannen en vrouwen een kolom aan naast de draaitabel en op plek 1 waarde 1, plek 2 waarde 1+2 enzovoort.**

# %% [markdown]
# 8. Onderzoek of voor de speeddates in deze onderzoeksgroep de volgende stelling juist is:
#
# "Mannen geven na een speeddate als beslissing (decision) vaker 'yes' aan dan vrouwen." $(2pt)$

# %% [markdown]
# ## Data analyseren
#
# We zijn klaar met verkenning, en hebben geleerd van de mogelijke tools die je kan gebruiken in Excel voor data analyse. Nu gaan we antwoord geven op de hoofdvraag: Wat beïnvloed de uitslag van een speeddate? Door middel van een aantal deelvragen te beantwoorden.
#
# ***Voor de vragen 7 tot en met 9 is het handig om video 8 te bekijken tot en met tijdstip 06:05.***

# %% [markdown]
# ### Video 8

# %%
video_id = "XHM0F1H_llE"
YouTubeVideo(video_id, width=600, height=400)

# %% [markdown]
# 9. Waarschijnlijk hangt de beslissing 'yes' of 'no' samen met het totaal aantal punten dat gegeven wordt op de onderdelen attractive $\mathrm{t} / \mathrm{m}$ shared interests (attr tm shar). Maak een nieuwe kolom 'totaal\_aantal\_punten' die het totaal van de kolommen attr $\mathrm{t} / \mathrm{m}$ shar weergeeft.
# ***Hint: maak een draaitabel met als waarde 'count of decision' en in de rijen en kolommen de gepaste variabelen. Pas daarna value field settings aan op % of row.***
# - (a) Ga aan de hand van de draaitabellen van mannen en vrouwen na of er een verband is tussen de beslissing 'yes'/'no' en het totaal aantal punten. $(3pt)$
#
# - (b) Ga na of er in dit verband een verschil is tussen mannen en vrouwen. $(2pt)$

# %% [markdown]
# 10. In deze opgave willen we je het belang van een proportionele dataset laten zien. Daarnaast is het voor deze opgave handig om video 8 te bekijken tot en met tijdstip 06:05.
#     - (a) Maak een draaitabel waarbij je ziet of er rassen zijn die een voorkeur hebben naar andere rassen. (Geef alleen de tabel je hoeft hier geen diagram te maken) $(3pt)$
#     - (b) Als het goed is zie je nu dat Eur/Cauc overal hoger is. Waardoor komt dit? $(1pt)$

# %% [markdown]
# 11. De onderzoekers verwachtten van tevoren dat bij een speeddate algemeen genomen de man de vrouw aantrekkelijker vindt dan andersom. Onderzoek of dit voor de gegevens van deze onderzoeksgroep juist is. Licht je antwoord toe. $(2 pt)$

# %% [markdown]
# 12. Ga na of er een verband is tussen het aantal matches en event nummer. Geef aan waarom wel/niet.  $(2pt)$

# %% [markdown]
# 13. Onderzoek of de volgende stelling waar is:
#
# "Als je een willekeurige speeddate uit deze dataset zou kiezen en je weet dat de cor\_int van die speeddate groter is dan 0,5, dan is de kans op een match bij deze speeddate groter dan 0,5 ".
#
# Licht je antwoord toe. $(2pt)$

# %% [markdown]
# 14. Geef telkens aan waarom onderstaand onderzoek wel of niet mogelijk is (Je hoeft het dus niet te onderzoeken. Een Ja/Nee antwoord met uitleg waarom wel/niet is voldoende):
#     - (a) Je kunt met behulp van de data in de dataset onderzoeken of de deelnemers een speeddate van 4 minuten te kort, te lang of precies goed vinden. $(1pt)$
#     - (b) Je kunt met behulp van de data in de dataset onderzoeken of het moment van de speeddate (vroeg of laat tijdens het event) van invloed is op de beslissing 'yes' of 'no'. $(1pt)$
#     - (c) Je kunt met behulp van de data in de dataset onderzoeken of deelnemers die zichzelf aantrekkelijk vinden meer kans hebben op een match dan deelnemers die zichzelf niet zo aantrekkelijk vinden. $(1pt)$
#     - (d) Je kunt met behulp van de data in de dataset onderzoeken of er bij grotere leeftijdsverschillen tussen de man en de vrouw vaker sprake is van een match. $(1pt)$

# %% [markdown]
# ## Conclusies trekken

# %% [markdown]
# 15. Gebaseerd op je antwoorden bij alle bovenstaande vragen, wat zou je kunnen zeggen over de hoofdonderzoeksvraag "Wat beïnvloed de uitslag van speeddates?" $(2pt)$

# %% [markdown]
# 16. Een laatste stap in de empirische cyclus is: evalueren en nieuwe problemen voorleggen. Bedenk twee nieuwe probleemstellingen die met deze dataset beantwoord kunnen worden. $(2pt)$

# %% [markdown]
# 17. Geef wat feedback over dit PO. Vond je dit een te lastige PO of vond je de moeilijkheidsgraad precies goed? Vertel ook wat je fijn vond aan dit PO en wat je minder fijn vond.  $(1pt)$

# %% [markdown]
# # Appendix

# %% [markdown]
# ![appendix_1.png](attachment:appendix_1.png)

# %% [markdown]
# ![appendix_2.png](attachment:appendix_2.png)
